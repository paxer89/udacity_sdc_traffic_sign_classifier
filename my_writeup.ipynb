# %% [markdown]
# # **Traffic Sign Recognition**
#
# ## Writeup
#
#
# ---
#
# **Build a Traffic Sign Recognition Project**
#
# The goals / steps of this project are the following:
# * Load the data set (see below for links to the project data set)
# * Explore, summarize and visualize the data set
# * Design, train and test a model architecture
# * Use the model to make predictions on new images
# * Analyze the softmax probabilities of the new images
# * Summarize the results with a written report
#
#
# [//]: # (Image References)
#
# [image1]: ./examples/Histogramme.png "Visualization"
# [image2]: ./examples/baustelle2.jpg "Grayscaling"
# [image3]: ./examples/random_noise.jpg "Random Noise"
# [image4]: ./examples/baustelle2.jpg "Traffic Sign 1"
# [image5]: ./examples/fussgaenger2.jpg "Traffic Sign 2"
# [image6]: ./examples/Stop2.jpg "Traffic Sign 3"
# [image7]: ./examples/50kmh2.jpg "Traffic Sign 4"
# [image8]: ./examples/durchfahrt2.jpg "Traffic Sign 5"
# [image9]: ./examples/durchfahrt3.jpg "Traffic Sign 6"
#
# ## Rubric Points
# ### Here I will consider the [rubric points](https://review.udacity.com/#!/rubrics/481/view) individually and describe how I addressed each point in my implementation.
#
# ---
# ### Writeup / README
#
# #### 1. Provide a Writeup / README that includes all the rubric points and how you addressed each one. You can submit your writeup as markdown or pdf. You can use this template as a guide for writing the report. The submission includes the project code.
#
# You're reading it! and here is a link to my [project code](/Traffic_Sign_Classifier.ipynb)
#
# ### Data Set Summary & Exploration
#
# #### 1. Provide a basic summary of the data set. In the code, the analysis should be done using python, numpy and/or pandas methods rather than hardcoding results manually.
#
# I used python to calculate summary statistics of the traffic
# signs data set:
#
# * The size of training set is 34799
# * The size of the validation set is 4410
# * The size of test set is 12630
# * The shape of a traffic sign image is 32x32x3
# * The number of unique classes/labels in the data set is 43
#
# #### 2. Include an exploratory visualization of the dataset.
#
# Here is an exploratory visualization of the data set. It is a bar chart showing how the data ist distributed over the labels for the training, validation an test date set. It shows, that the different sign types aren't equally covered by the date sets.
# though the relativ distribution of the sign types is nearly the same for the training, validation and testing data set.
#
# ![alt text][image1]
#
# ### Design and Test a Model Architecture
#
# #### 1. Describe how you preprocessed the image data. What techniques were chosen and why did you choose these techniques? Consider including images showing the output of each preprocessing technique. Pre-processing refers to techniques such as converting to grayscale, normalization, etc. (OPTIONAL: As described in the "Stand Out Suggestions" part of the rubric, if you generated additional data for training, describe why you decided to generate additional data, how you generated the data, and provide example images of the additional data. Then describe the characteristics of the augmented training set like number of images in the set, number of images for each class, etc.)
#
# As a first step, I plottet some random sign images and the related label to check if the date set ist correctly labeled.
#
# I normalized the image data  with `(X_train - 127.5)/127.5 ` to approx sclae of -1 to 1 to avoid too large neccesary weights while training.
#
# Then I randomized the training date set with
#
# ```python
# from sklearn.utils import shuffle
# X_train, y_train = shuffle(X_train, y_train)
# ```
# in case that the set is sorted somehow which would affect training.
#
#
# #### 2. Describe what your final model architecture looks like including model type, layers, layer sizes, connectivity, etc.) Consider including a diagram and/or table describing the final model.
#
# My final model consisted of the following layers, pretty similar to LeNet:
#
# | Layer         		|     Description	        					|
# |:---------------------:|:---------------------------------------------:|
# | Input         		| 32x32x3 RGB image   							|
# | Convolution 5x5     	| 1x1 stride, valid padding, outputs 28x28x6 	|
# | RELU					|												|
# | Max pooling	      	| 2x2 stride,  outputs 14x14x6 		     		|
# | Convolution 5x5	    | 1x1 stride, valid padding, outputs 10x10x16	|
# | RELU             	    |       								    	|
# | Max pooling	      	| 2x2 stride,  outputs 5x5x16 		     		|
# | Flatten        	    | output 400  									|
# | Fully connected		| output 120   									|
# | RELU  				|           									|
# | Dropout				| 50%											|
# | Fully connected		| output 84   									|
# | RELU  				|           									|
# | Dropout				| 50%											|
# | Fully connected		| output 43   									|
# | Dropout				| 50%											|
#
#
# #### 3. Describe how you trained your model. The discussion can include the type of optimizer, the batch size, number of epochs and any hyperparameters such as learning rate.
#
# To train the model, I used an batch size of 128 and 25 epochs and a dropout rate of 50%.
# The learning rat ewas 0.0005.
# As optimizer AdamOptimizer was used.
#
# Training pipeline:
#
# ```python
# logits = LeNet(x)
# cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
# loss_operation = tf.reduce_mean(cross_entropy)
# optimizer = tf.train.AdamOptimizer(learning_rate = rate)
# training_operation = optimizer.minimize(loss_operation)
# ```
#
#
# #### 4. Describe the approach taken for finding a solution and getting the validation set accuracy to be at least 0.93. Include in the discussion the results on the training, validation and test sets and where in the code these were calculated. Your approach may have been an iterative process, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think the architecture is suitable for the current problem.
#
# My final model results were:
# * training set accuracy of 98.7%
# * validation set accuracy of 93,9%
# * test set accuracy of 93,4%
#
# I started with the LeNet architechture from the lab in the previous lesson. At first I had to adjust the parameters to the different image size und the 3 color channels. After normalizing the images the model had pretty good results on the training data but a huge gap between the training date accuracy and the validation accuracy. So added dropouts with a dropout probability of 50% to the fully connected layers to prevent the modle from overfitting.
# Afterwards I played around a bit with the hyperparameters. I ended up with half of the initial learning rate and 30 training epochs. With that training rate the modle seemed to not further Improve after 30 epochs.
#
#
# There are many possibilities to further improve my model. I could play around with the amount of layers and the depth in the convoloutional layers. I could try to exchange the max pooling layers for example with dropouts, maybe with a lower dropout probability as in the fully connected layers. I could also try out inception moudules.
#
# Another way to improve the model would be to augment the training data set for example by rotating the images or by "zooming" in and out. that should mostly helpt with the images found in the internet which aren't completely similar to the training data set.
#
#
# ### Test a Model on New Images
#
# #### 1. Choose five German traffic signs found on the web and provide them in the report. For each image, discuss what quality or qualities might be difficult to classify.
#
# Here are six German traffic signs that I found on the web:
#
# ![alt text][image4] ![alt text][image5] ![alt text][image6]
# ![alt text][image7] ![alt text][image8] ![alt text][image9]
#
# The last image might be difficult to classify because there is an extra sign beneath an a bigger share of the pciture not showing the sign.
#
# #### 2. Discuss the model's predictions on these new traffic signs and compare the results to predicting on the test set. At a minimum, discuss what the predictions were, the accuracy on these new predictions, and compare the accuracy to the accuracy on the test set (OPTIONAL: Discuss the results in more detail as described in the "Stand Out Suggestions" part of the rubric).
#
# Here are the results of the prediction:
#
# | Image			        |     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | Stop Sign      		| Stop sign   									|
# | Speed limit (50km/h)  | Speed limit (50km/h)							|
# | Road work				| Road work										|
# | Children crossing		| Children crossing				 				|
# | No vehicles			| No vehicles       							|
# | No vehicles			| Yield             							|
#
# The model was able to correctly guess 5 of the 6 traffic signs, which gives an accuracy of 83.3%.
#
# The first 5 images were clearly visible and similarly scaled as the training date so it was expected that they're correctly classified. The last one which was too different form the training data unfortunately wasn't correctly classified.
#
#
# #### 3. Describe how certain the model is when predicting on each of the five new images by looking at the softmax probabilities for each prediction. Provide the top 5 softmax probabilities for each image along with the sign type of each probability. (OPTIONAL: as described in the "Stand Out Suggestions" part of the rubric, visualizations can also be provided such as bar charts)
#
# For the first 5 images, the model output is a probability of nearly one for the correct class.
#
# Unfortunatly for the 6th image the model output is a wrong class with a probability of nearly 1. The correct class shows up on fourth place with a prbability of only 1.22e-11. thats not what's ideally expected from a model. If the model is unsafe in it's prediction it should output a largely spreaded probability over different classes.
